# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("spambase.csv")

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
predict = 'spam'
X = np.array(df.drop([predict], axis=1))
Y = np.array(df[predict])

# %%
df.describe().T
# Out:
#                              count        mean         std  min     25%  \
# word_freq_make              4601.0    0.104553    0.305358  0.0   0.000
# word_freq_address           4601.0    0.213015    1.290575  0.0   0.000
# word_freq_all               4601.0    0.280656    0.504143  0.0   0.000
# word_freq_3d                4601.0    0.065425    1.395151  0.0   0.000
# word_freq_our               4601.0    0.312223    0.672513  0.0   0.000
# word_freq_over              4601.0    0.095901    0.273824  0.0   0.000
# word_freq_remove            4601.0    0.114208    0.391441  0.0   0.000
# word_freq_internet          4601.0    0.105295    0.401071  0.0   0.000
# word_freq_order             4601.0    0.090067    0.278616  0.0   0.000
# word_freq_mail              4601.0    0.239413    0.644755  0.0   0.000
# word_freq_receive           4601.0    0.059824    0.201545  0.0   0.000
# word_freq_will              4601.0    0.541702    0.861698  0.0   0.000
# ...

# %%
from scipy.stats import zscore

df_zscore = df.apply(zscore)
df_zscore
print("original df:", df.shape)
# Out:
# original df: (4601, 58)

# %%
outliers = df_zscore[(df_zscore.abs() > 3).any(axis=1)]
print(outliers)
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 2          -0.145921          -0.165072       0.851723       -0.0469
# 5          -0.342434          -0.165072      -0.556761       -0.0469
# 6          -0.342434          -0.165072      -0.556761       -0.0469
# 7          -0.342434          -0.165072      -0.556761       -0.0469
# 8           0.148847          -0.165072       0.355778       -0.0469
# ...              ...                ...            ...           ...
# 4588       -0.342434          -0.165072       5.454094       -0.0469
# 4591       -0.342434          -0.165072      -0.556761       -0.0469
# 4592       -0.342434          -0.165072       1.922965       -0.0469
# 4593       -0.342434          -0.165072      -0.556761       -0.0469
# 4594       -0.342434          -0.165072      -0.556761       -0.0469
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
df = df.drop(index=outliers.index)
print("df after deleting noises:", df.shape)
# Out:
# df after deleting noises: (2185, 58)

# %%
from sklearn import preprocessing

normalized_df = preprocessing.normalize(df)
print(normalized_df)
x = normalized_df
# Out:
# [[0.00000000e+00 2.24833587e-03 2.24833587e-03 ... 2.14294513e-01
#   9.76620894e-01 3.51302480e-03]
#  [2.03297010e-04 2.71062679e-04 4.84040499e-04 ... 9.77761808e-02
#   9.95187266e-01 9.68080998e-04]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.04908666e-01
#   9.78438879e-01 5.12271664e-03]
#  ...
#  [2.53812946e-03 0.00000000e+00 2.53812946e-03 ... 5.07625892e-02
#   9.98330921e-01 0.00000000e+00]
#  [1.22759766e-02 0.00000000e+00 0.00000000e+00 ... 6.39373781e-02
#   9.97423098e-01 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.59858723e-02 ... 1.22968248e-01
#   9.83745986e-01 0.00000000e+00]]

# %%
from sklearn.linear_model import LogisticRegression

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
mymodel = LogisticRegression(solver='liblinear', max_iter=1000)
mymodel.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score

y_pred = mymodel.predict(x_test)
accu = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accu}")
# Out:
# Accuracy: 0.9120521172638436

# %% [markdown]
# # Preceision

# %%
from sklearn.metrics import precision_score

pre = precision_score(y_test, y_pred)
print(f"Precision: {pre}")
# Out:
# Precision: 0.9055555555555556

# %% [markdown]
# # Recall

# %%
from sklearn.metrics import recall_score
 
recall = recall_score(y_test, y_pred)
print(f"Recall: {recall}")
# Out:
# Recall: 0.8739946380697051

# %% [markdown]
# # F1 Score

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred)
print(f"F1 score: {f1}")
# Out:
# F1 score: 0.8894952251023193

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %% [markdown]
# # Using L1

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
mymodel = LogisticRegression(penalty='l1',solver='liblinear', max_iter=1000)
mymodel.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', solver='liblinear')

# %%
y_pred = mymodel.predict(x_test)
accu = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accu}")
# Out:
# Accuracy: 0.9185667752442996

# %% [markdown]
# # Using L2

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
mymodel = LogisticRegression(penalty='l2',solver='liblinear', max_iter=1000)
mymodel.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
y_pred = mymodel.predict(x_test)
accu = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accu}")
# Out:
# Accuracy: 0.9261672095548317
